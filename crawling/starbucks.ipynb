# %%
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome('../chromedriver')
url = 'https://www.starbucks.co.kr/store/store_map.do?disp=locale'
driver.get(url)
time.sleep(10)

# %%
gwangju_btn = driver.find_element_by_css_selector('#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(3) > a')
gwangju_btn.click()
time.sleep(2)

# %%
all_btn = driver.find_element_by_css_selector('#mCSB_2_container > ul > li:nth-child(1) > a')
all_btn.click()

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
stores = soup.select('#mCSB_3_container > ul > li')

# %%
data = pd.DataFrame(columns=['지점 명', '주소', '번호'])
for store in stores:
    name = store.select_one('strong').text
    print('지점 명: ' + name)
    (address, number) = str(store.select_one('p').encode_contents(), encoding='utf-8').split('<br/>')
    print('주소: ' + address)
    print('번호: ' + number)
    print('----------------------------------')
    data = data.append({'지점 명': name, '주소': address, '번호': number}, ignore_index=True)
data.head()
# Out:
# 지점 명: 광주운남DT
# 주소: 광주광역시 광산구 임방울대로 156 (운남동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주선운DT
# 주소: 광주광역시 광산구 선운로 20번길 63
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주산정DT
# 주소: 광주광역시 광산구 용아로 342 (산정동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주흑석DT
# 주소: 광주광역시 광산구 사암로 367 (산정동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주송정역
# 주소: 광주광역시 광산구 상무대로205번길 6 (송정동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주수완DT
# 주소: 광주광역시 광산구 임방울대로 487 (수완동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주신가DT
# 주소: 광주광역시 광산구 목련로 335 (신가동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주쌍암
# 주소: 광주광역시 광산구 첨단중앙로 158 (쌍암동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주장덕
# 주소: 광주광역시 광산구 장신로 85 (장덕동)
# 번호: 1522-3232
# ----------------------------------
# 지점 명: 광주하남
# 주소: 광주광역시 광산구 사암로216번길 38-16, 1~2층 (우산동)
# 번호: 1522-3232
# ----------------------------------
# ...

# %%
data.to_csv('./200528_starbucks.csv', index=False)
